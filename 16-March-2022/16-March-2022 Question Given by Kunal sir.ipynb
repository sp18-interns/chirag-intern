# %%
"""
class Shape:
    def __init__(self,Circle,Square,Rectangle,Triangle):
        self.Circle = Circle
        self.Square = Square
        self.Rectangle = Rectangle
        self.Triangle = Triangle
        
class Rectangle(Shape,length,width):
    self.length = length
    self.width = width
    
     def count_area(self):
        self.area = self.length * self.width

    def count_perimeter(self):
        self.perimeter = 2 * (self.length + self.width)
        
R = Rectangle(2,5)
    R.count_area()
    R.count_perimeter()
    print(R) 
    
"""
# Out:
# '\nclass Shape:\n    def __init__(self,Circle,Square,Rectangle,Triangle):\n        self.Circle = Circle\n        self.Square = Square\n        self.Rectangle = Rectangle\n        self.Triangle = Triangle\n        \nclass Rectangle(Shape,length,width):\n    self.length = length\n    self.width = width\n    \n     def count_area(self):\n        self.area = self.length * self.width\n\n    def count_perimeter(self):\n        self.perimeter = 2 * (self.length + self.width)\n        \nR = Rectangle(2,5)\n    R.count_area()\n    R.count_perimeter()\n    print(R)        \n'

# %%
"""
class Shape:
    def __init__(self,Circle,Square,Rectangle,Triangle):
        self.Circle = Circle
        self.Square = Square
        self.Rectangle = Rectangle
        self.Triangle = Triangle


class circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*(self.radius**2)
    def perimeter(self):
        return 2*3.14*self.radius
    
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return (length*width)
    def perimeter(self):
        return 2*(length+width)    
    
r = int(input("Enter radius of circle: "))
circle(r)
print("Area of circle:",round(obj.area(),2))
print("Perimeter of circle:",round(obj.perimeter(),2))

l = int(input("Enter the length of Rectangle: "))
b = int(input("Enter the breadth of Rectangle: "))
Rectangle(l,b)
print("Area of Rectangle:",round(obj.area(),2))





"""
# Out:
# '\nclass Shape:\n    def __init__(self,Circle,Square,Rectangle,Triangle):\n        self.Circle = Circle\n        self.Square = Square\n        self.Rectangle = Rectangle\n        self.Triangle = Triangle\n\n\nclass circle(Shape):\n    def __init__(self,radius):\n        self.radius=radius\n    def area(self):\n        return 3.14*(self.radius**2)\n    def perimeter(self):\n        return 2*3.14*self.radius\n    \nclass Rectangle(Shape):\n    def __init__(self,length,width):\n        self.length=length\n        self.width=width\n    def area(self):\n        return (length*width)\n    def perimeter(self):\n        return 2*(length+width)    \n    \nr = int(input("Enter radius of circle: "))\ncircle(r)\nprint("Area of circle:",round(obj.area(),2))\nprint("Perimeter of circle:",round(obj.perimeter(),2))\n\nl = int(input("Enter the length of Rectangle: "))\nb = int(input("Enter the breadth of Rectangle: "))\nRectangle(l,b)\nprint("Area of Rectangle:",round(obj.area(),2))\n\n\n\n\n\n'

# %%
class Shape():
    def __init__(self,area,perimeter):
        self.area = area 
        self.perimeter = perimeter
        
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 3.14*(self.radius**2)
    def perimeter(self):
        return 2*3.14*self.radius
    
   
   
r = int(input("Enter the radius of circle: "))
c = Circle(r)
    
     
print("area of circle",c.area())
print('perimeter of circle', c.perimeter()) 
    
    
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def area(self):
        return self.length*self.width
    def perimeter(self):
        return 2*(self.length+self.width)
    
   
   
l = int(input("Enter the length: "))
w = int(input("Enter the width: "))
c = Rectangle(l,w)

    
     
print("Area of Rectangle: ",c.area())
print("Perimeter of rectangle: ",c.perimeter()) 


class Square(Shape):
    def __init__(self,equal_side):
        self.equal_side = equal_side
    def area(self):
        return self.equal_side*self.equal_side
    def perimeter(self):
        return 4*(self.equal_side)
    
   
   
a = int(input("Enter the sides of square: "))

c = Square(a)

    
     
print("Area of Square: ",c.area())
print("Perimeter of square: ",c.perimeter()) 




class Triangle(Shape):
    def __init__(self,base,height):
        self.base = base
        self.height= height
    def area(self):
        return 0.5*self.base*self.height
    
    
   
   
a = int(input("Enter the base: "))
b= int(input("Enter the height: "))

T = Triangle(a,b)

    
     
print("Area of Triangle: ",T.area())
# Out:
# Enter the radius of circle: 2
# area of circle 12.56
# perimeter of circle 12.56
# Enter the length: 5
# Enter the width: 4
# Area of Rectangle:  20
# Perimeter of rectangle:  18
# Enter the sides of square: 2
# Area of Square:  4
# Perimeter of square:  8
# Enter the base: 2
# Enter the height: 6
# Area of Triangle:  6.0
